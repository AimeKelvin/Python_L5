# %%
import pandas as pd

# Load CSV
df = pd.read_csv('/mnt/data/student_performance.csv')

# Display first few rows
df.head()

# Get dataset info (columns, types, missing values)
df.info()

# Describe numerical columns for statistics overview
df.describe()

# Check for duplicate rows
df.duplicated().sum()

# %%
# Load the CSV file
df = pd.read_csv('/mnt/data/student_performance.csv')

# Explanation:
# pd.read_csv() loads a CSV file into a pandas DataFrame
# df.head() shows the first 5 rows
# df.info() gives column types and missing value info

# %%
# 1. Remove duplicates
df = df.drop_duplicates()

# 2. Fill missing numerical values (example: fill with mean)
for col in ['math score', 'reading score', 'writing score']:
    df[col].fillna(df[col].mean(), inplace=True)

# 3. Fill missing categorical values (example: mode)
for col in ['gender', 'race/ethnicity', 'parental level of education', 'lunch', 'test preparation course']:
    df[col].fillna(df[col].mode()[0], inplace=True)

# 4. Correct data types if needed
# Example: convert scores to integer
for col in ['math score', 'reading score', 'writing score']:
    df[col] = df[col].astype(int)

# Check cleaned dataset
df.info()
df.head()
