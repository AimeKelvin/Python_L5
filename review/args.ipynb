# %%
def multiply(a,b):
    return a * b

multiply(4, 5)
# Out:
# 20

# %%
#in this code tha parameters are base and exp while the arguments are 2 and 3
def power(base, exp):
    return base ** exp

power(2, 3)
# Out:
# 8

# %%
def student_info(*, name, age, course="SWD"):
    print(f"Name: {name}, Age: {age}, Course: {course}")

student_info(name="ice", age=22)
# Out:
# Name: ice, Age: 22, Course: SWD

# %%
def greet_user(name, language="English"):
    print(f"{name}, hello!!")

greet_user("Alice")
# Out:
# Alice, hello!!

# %%
def add_score(score, scores=None):
    if scores is None:
        scores = []
    scores.append(score)
    return scores

# %%
def add(a,b,c, /):
    print(a + b + c)

#add(1,2,3)  # valid
#add(a=1, b=2, c=3)  # invalid

# %%
def user(name, *, isAdmin = False):
 print(f"Welcome admin {name}, isAdmin: {isAdmin}")

user("Bob")  # isAdmin defaults to False
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 def user(name, *, isAdmin = False):
#       2  print(f"Welcome admin {name}, isAdmin: {isAdmin}")
# ----> 4 user("Alice", True)
#       5 user("Bob")
#
# TypeError: user() takes 1 positional argument but 2 were given

# %%
def sumAll(*args):
    total = 0
    for num in args:
        total += num
    return total
